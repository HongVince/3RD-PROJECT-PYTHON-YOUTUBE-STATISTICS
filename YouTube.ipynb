# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns
# Out:
# C:\Users\Vince\AppData\Local\Temp\ipykernel_18216\4101594710.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("Global Youtube Statistics.csv", encoding = "latin1")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df.tail(20)
# Out:
#      rank                                       Youtuber  subscribers  \
# 975   976                              Gustavo Parï¿½ï¿½     12400000
# 976   977                                 SAAIHALILINTAR     12400000
# 977   978                                       Timba Vk     12400000
# 978   979                       Heidi and Zidane HZHtube     12400000
# 979   980  DaniRep | +6 Vï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï     12400000
# 980   981                                       Zee Kids     12400000
# 981   982                               Pari's Lifestyle     12400000
# 982   983                                DisneyChannelUK     12400000
# 983   984                                       MoniLina     12400000
# 984   985                           bharatzkitchen HINDI     12400000
# 985   986                                           TKOR     12400000
# 986   987                                      ANNA KOVA     12400000
# ...

# %%
df.describe()
# Out:
#         rank  subscribers     video views   uploads  video_views_rank  \
# count 995.00       995.00          995.00    995.00            994.00
# mean  498.00  22982412.06  11039537052.04   9187.13         554248.90
# std   287.38  17526105.34  14110844376.83  34151.35        1362782.21
# min     1.00  12300000.00            0.00      0.00              1.00
# 25%   249.50  14500000.00   4288145410.00    194.50            323.00
# 50%   498.00  17700000.00   7760819588.00    729.00            915.50
# 75%   746.50  24600000.00  13554701853.00   2667.50           3584.50
# max   995.00 245000000.00 228000000000.00 301308.00        4057944.00
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count        879.00             962.00                            939.00
# mean         386.05             745.72                      175610284.79
# std         1232.24            1944.39                      416378166.21
# ...

# %%
df.isna().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
pd.set_option("display.float_format", "{:.3f}".format)

# %% [markdown]
# =============================Upload Mean=============================

# %%
category_uploads_mean = df.groupby("category")["uploads"].mean()
category_uploads_mean
# Out:
# category
# Autos & Vehicles           1898.500000
# Comedy                     1119.753623
# Education                  3142.866667
# Entertainment             11908.481328
# Film & Animation           2799.652174
# Gaming                     4313.414894
# Howto & Style              1673.350000
# Movies                     3553.000000
# Music                      2335.509901
# News & Politics          112484.384615
# Nonprofits & Activism    102912.000000
# People & Blogs             9190.780303
# Pets & Animals             4451.500000
# Science & Technology       2114.058824
# Shows                     27443.692308
# Sports                    14493.727273
# Trailers                   6839.000000
# Travel & Events             766.000000
# Name: uploads, dtype: float64

# %%
category_uploads_mean.sort_values(ascending= False, inplace = True)

# %%
category_uploads_mean.head(10).plot(kind = "bar")
plt.title ("The Mean of Subscribers by Category")
plt.xlabel("Category")
plt.ylabel("Uploads")
plt.xticks(rotation = 90)
plt.show()

# %%
channel_type_counts = df["channel_type"].value_counts()
channel_type_counts
# Out:
# channel_type
# Entertainment    304
# Music            216
# People           101
# Games             98
# Comedy            51
# Education         49
# Film              42
# Howto             36
# News              30
# Tech              17
# Sports            13
# Autos              3
# Animals            3
# Nonprofit          2
# Name: count, dtype: int64

# %%
channel_type_counts.head(5).plot(kind = "pie", autopct = "%1.1f%%")
plt.title("Channel Type Distribution")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df["subscribers"], df["video views"])
plt.title("Scatter Plot of Youtuber against View Views")
plt.xlabel("Subscribers")
plt.ylabel("Video Views")
plt.show()

# %%
total_subscribers_by_country = df.groupby("Country")["subscribers"].sum().sort_values(ascending = False)

# %%
total_subscribers_by_country
# Out:
# Country
# United States           7329500000
# India                   4310600000
# Brazil                  1221800000
# United Kingdom           917400000
# Mexico                   626900000
# Indonesia                534100000
# South Korea              481700000
# Russia                   407200000
# Thailand                 386500000
# Spain                    385100000
# Canada                   363900000
# Argentina                328500000
# Colombia                 264500000
# Philippines              240100000
# Japan                    189100000
# Saudi Arabia             179100000
# Australia                172000000
# Pakistan                 155400000
# United Arab Emirates     148200000
# Ukraine                  125600000
# Germany                  116400000
# Turkey                    91600000
# Chile                     87200000
# France                    83900000
# Jordan                    67000000
# Sweden                    63000000
# ...

# %%
total_subscribers_by_country.head(10).plot(kind = "bar")
plt.title("Total Number of Subsribers by Country")
plt.xlabel("Country")
plt.ylabel("Subscribers")
plt.xticks(rotation = 90)
plt.show()

# %%
df.groupby("created_year")["subscribers"].mean().sort_values(ascending = True)
# Out:
# created_year
# 2022.000   13640000.000
# 2021.000   18573913.043
# 2019.000   18639393.939
# 2017.000   18666176.471
# 2014.000   20618367.347
# 2010.000   20670833.333
# 2015.000   21247945.205
# 2020.000   21350000.000
# 2011.000   21800000.000
# 2018.000   23060869.565
# 2016.000   23101298.701
# 2009.000   23105769.231
# 2008.000   23652173.913
# 2012.000   24038235.294
# 2013.000   24527631.579
# 2007.000   24902040.816
# 2005.000   25829166.667
# 2006.000   31884615.385
# 1970.000   36300000.000
# Name: subscribers, dtype: float64

# %%
pd.set_option("display.float_format", "{:.0f}".format)

# %%
df.groupby("channel_type")["video_views_rank"].median().sort_values(ascending = False)
# Out:
# channel_type
# Autos           3468229
# Tech               2420
# Games              1944
# People             1868
# Howto              1574
# Nonprofit          1538
# Sports             1186
# Comedy             1033
# Film                880
# Entertainment       796
# News                612
# Education           538
# Music               385
# Animals             136
# Name: video_views_rank, dtype: float64

# %%
df.groupby("Country")["subscribers_for_last_30_days"].max().sort_values(ascending = False)
# Out:
# Country
# United States          8000000
# Indonesia              5500000
# United Arab Emirates   3400000
# South Korea            3200000
# Sweden                 3000000
# Turkey                 2100000
# India                  2000000
# Italy                  2000000
# Argentina              1900000
# Russia                 1600000
# Colombia               1600000
# Pakistan               1300000
# Kuwait                 1300000
# Latvia                 1200000
# Japan                  1100000
# Brazil                 1100000
# Germany                 900000
# Spain                   800000
# United Kingdom          600000
# Mexico                  600000
# Australia               600000
# Chile                   500000
# Philippines             500000
# Saudi Arabia            500000
# Canada                  400000
# Thailand                300000
# Jordan                  300000
# Ecuador                 300000
# Ukraine                 230000
# Singapore               200000
# ...

# %%
df.groupby("created_month")["subscribers"].sum()
# Out:
# created_month
# Apr    1581200000
# Aug    1813600000
# Dec    1577300000
# Feb    1533800000
# Jan    2254600000
# Jul    1922300000
# Jun    1846400000
# Mar    2320500000
# May    1997700000
# Nov    1930200000
# Oct    1503700000
# Sep    2496200000
# Name: subscribers, dtype: int64

# %%
df.groupby("category")["video views"].std()
# Out:
# category
# Autos & Vehicles         2964425984
# Comedy                   6406251669
# Education               25572139026
# Entertainment           10128204611
# Film & Animation        10899550881
# Gaming                   5835933598
# Howto & Style            4300326961
# Movies                   3353301875
# Music                   17782784424
# News & Politics          5165961805
# Nonprofits & Activism    2698145850
# People & Blogs          12510420847
# Pets & Animals           6475165093
# Science & Technology     2937981619
# Shows                   43723894662
# Sports                  21703831459
# Trailers                 1382496086
# Travel & Events                 NaN
# Name: video views, dtype: float64

# %%
df.groupby("Country")["Unemployment rate"].min().sort_values(ascending = True)
# Out:
# Country
# Thailand                 1
# Cuba                     2
# Vietnam                  2
# Philippines              2
# Kuwait                   2
# Japan                    2
# United Arab Emirates     2
# Germany                  3
# Netherlands              3
# Peru                     3
# Malaysia                 3
# Mexico                   3
# United Kingdom           4
# Ecuador                  4
# El Salvador              4
# Singapore                4
# South Korea              4
# Bangladesh               4
# China                    4
# Pakistan                 4
# Switzerland              5
# Russia                   5
# Indonesia                5
# Australia                5
# India                    5
# Canada                   6
# Saudi Arabia             6
# Sweden                   6
# Latvia                   7
# Finland                  7
# Chile                    7
# Samoa                    8
# France                   8
# Venezuela                9
# ...

# %%
df.groupby("channel_type")["uploads"].sum()
# Out:
# channel_type
# Animals            42868
# Autos                949
# Comedy             81722
# Education         146355
# Entertainment    3345035
# Film              114654
# Games             399473
# Howto              79417
# Music             424950
# News             3989151
# Nonprofit         205824
# People            117424
# Sports            158995
# Tech               33780
# Name: uploads, dtype: int64

# %%
df.groupby(["Latitude", "Longitude"]).size()
# Out:
# Latitude  Longitude
# -38       -64           13
# -36       -72            3
# -25       134            9
# -14       -52           62
#           -172           1
# -9        -75            1
# -2        -78            2
# -1        114           28
# 1         104            3
# 4         102            1
# 5         -74           11
# 6         -67            1
# 13        122           12
#           -60            1
# 14        -89            1
#           108            3
# 16        101           18
# 21        79           168
# 22        -78            1
# 23        54             7
# 24        -103          33
#           90             1
#           45             9
# 27        31             2
# 29        47             1
# 30        69             6
# 31        36             3
# 32        -7             1
# 33        44             2
# 34        68             1
# 36        104            1
#           128           17
#           138            5
# ...

# %%
sns.boxplot( x = "channel_type", y = "highest_monthly_earnings", data = df)
plt.title("Highest Earning Channel Type Distribution")
plt.xticks(rotation = 90)
plt.show()

# %%
df.groupby(["category", "Country"])["subscribers"].sum().unstack().plot(kind = "bar", stacked = True)
plt.title("Breakdown of Subscribers by Country and Category")
plt.xlabel("Category")
plt.ylabel("Total Subscribers")
plt.legend(title = "Country", bbox_to_anchor = (1.05, 1), loc = "upper left")
plt.xticks(rotation = 90)
plt.show()

# %%
plt.scatter(df["Gross tertiary education enrollment (%)"], df["subscribers"], alpha = 0.5)
plt.title("Subscribers vs. Gross Tertiary Education Enrollment Scatter Plot")
plt.xlabel("Gross Education Enrollment")
plt.ylabel("Subscribers")
plt.show()

# %%
df.groupby("channel_type")["Unemployment rate"].mean().head().sort_values(ascending = False).plot(kind = "bar")
plt.title("Average Unemployment Rate by Channel Type")
plt.xlabel("Channel Type")
plt.ylabel("Average Unemployment Rate")
plt.xticks(rotation = 90)
plt.show()

# %%
df.groupby(["created_year", "channel_type"])["subscribers"].mean().unstack().tail().plot(kind = "bar", width = 1)
plt.title("Average Subscribers by Channel Type and Created Year")
plt.xlabel("Created Year")
plt.ylabel("Subscribers")
plt.xticks(rotation = 45)
plt.legend(title = "Channel Type", bbox_to_anchor = (1.05, 1), loc = "upper left")
plt.show()

# %%
df.groupby(["created_year","created_month"])["subscribers"].sum().unstack().head().plot(kind = "area", stacked = True)
plt.title("Subscribers Accumulation Over Time")
plt.xlabel("year")
plt.ylabel("Total Subscribers")
plt.legend(title = "Month", bbox_to_anchor = (1.05,1), loc = "upper left")
plt.xticks(rotation = 45)
plt.show()

# %%
df.groupby(["created_year", "Country"])["highest_yearly_earnings"].mean().unstack().head().plot(kind = "line", marker = "o")
plt.title("Trend of Highest Yearly Earnings by Created Year and Country")
plt.xlabel("Created Year")
plt.ylabel("Average Highest Yearly Earnings")
plt.legend(title = "Country", bbox_to_anchor = (1.05,1), loc = "upper left")
plt.xticks(rotation = 45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
category_highest_monthly_earnings_sum = df.groupby("category")["highest_monthly_earnings"].sum()

# %%
category_highest_monthly_earnings_sum.sort_values(ascending = False, inplace = True)

# %%
category_highest_monthly_earnings_sum
# Out:
# category
# Entertainment           150056865
# Music                   111564524
# People & Blogs           72183154
# Comedy                   46113543
# Film & Animation         33704283
# Education                31283000
# Shows                    26489600
# Gaming                   25559111
# News & Politics          16708431
# Sports                    8876300
# Howto & Style             7711962
# Science & Technology      3434735
# Pets & Animals            3177729
# Autos & Vehicles          2172700
# Movies                     909400
# Nonprofits & Activism      780800
# Trailers                   723800
# Travel & Events            124000
# Name: highest_monthly_earnings, dtype: float64

# %%
category_highest_monthly_earnings_sum.head().plot(kind = "pie", autopct = "%1.1f%%")
plt.title("Percentage of Highest Monthly Earnings by Category")
plt.ylabel("")
plt.show()

# %%
channel_created_subscribers_mean = df.groupby(["channel_type","created_year"])["subscribers_for_last_30_days"].mean().unstack()

# %%
channel_created_subscribers_mean
# Out:
# created_year    1970   2005   2006   2007   2008   2009    2010   2011   2012  \
# channel_type
# Animals          NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# Autos            NaN    NaN      2 500000    NaN    NaN     NaN    NaN      9
# Comedy           NaN 400000 100000 100000 200000 400000     NaN  50000    NaN
# Education        NaN    NaN 700000    NaN 200000 100000  200000 200000 350000
# Entertainment 300000 325000 306250 342857 450000 480000  212575 442857 760000
# Film             NaN      1 333333    NaN 100000    NaN     NaN 225008 300000
# Games            NaN 100000    338  50006 100000 200000       3 150000 376923
# Howto            NaN 500000    NaN    NaN    NaN 100000  100000    NaN    NaN
# Music            NaN 160000 433334 146160 185385 153846  175000 158829 200000
# News             NaN 100000 205000 440000 100000 275000  100000    NaN 400000
# Nonprofit        NaN    NaN    NaN    NaN    NaN 100000     NaN    NaN    NaN
# ...

# %%
sns.heatmap(channel_created_subscribers_mean.head(5), cmap ="YlGnBu", annot = True)
plt.title("Mean Subscribers for the Last 30 Days by Channel Type and Created Year")
plt.xlabel("Created Year")
plt.ylabel("Channel Type")
plt.show()

# %%
df.groupby("created_month")["subscribers_for_last_30_days"].mean().plot(kind = "line", marker = "o")
plt.title("Average Subscribers for the Last 30 Days")
plt.xlabel("Month")
plt.ylabel("Average Subscribers for the Last 30 Days")
plt.xticks(rotation = 45)
plt.show()
